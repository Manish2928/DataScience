# %% [markdown]
# <a href="https://colab.research.google.com/github/Manish2928/DataScience/blob/main/Feature-Engineering/Handling_Imbalanced_Dataset_Using_Smote_127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Handling Imbalanced Dataset Using Smote**

# %% [markdown]
# # SMOTE (Synthetic Minority Oversampling Technique)

# %%
from sklearn.datasets import make_classification

# %%
x,y =make_classification(n_samples=1000, n_redundant=0, n_features=2, n_clusters_per_class=1,weights=[0.90], random_state=12)

# %%
import pandas as pd
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
final_df = pd.concat([df1,df2],axis=1)

# %%
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df.tail()
# Out:
#            f1        f2  target
# 995 -0.712495 -0.880452       0
# 996 -2.625830 -2.827891       0
# 997 -1.326439 -1.815178       0
# 998 -0.833486 -0.514647       0
# 999 -0.302876 -0.575975       0

# %%
final_df.shape
# Out:
# (1000, 3)

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
# Transform the dataset

oversampling = SMOTE()
x,y=oversampling.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (1800, 2)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
final_df = pd.concat([df1,df2],axis=1)

# %%
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])
